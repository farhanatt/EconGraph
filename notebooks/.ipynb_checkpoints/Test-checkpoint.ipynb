# %%
# %matplotlib inline
import EconGraph
from EconGraph import *
import importlib

importlib.reload(EconGraph)
# Out:
# <module 'EconGraph' from '/Users/Farhan/Documents/CMC/DSL/EconGraph/notebooks/EconGraph.py'>

# %%
DemandCurve().shift("up").show()
SupplyCurve().shift("down").show()

# %%
DemandCurve().shift("up").show()

# %%
DemandCurve().slope("vertical").show()

# %%
SupplyCurve().shift("up").show()

# %%
SupplyCurve().slope("up").show()

# %%
SupplyCurve().slope("down").show()

# %%
SupplyCurve().slope("horizontal").show()

# %%
SupplyCurve().slope("vertical").show()
DemandCurve().show()

# %%
cir1 = pylab.Circle((0,0), radius=0.75, fc='w')
cir2 = pylab.Circle((0,0), radius=0.5, fc='w')
arr = pylab.Arrow(0.33, 0.45, 0.1, 0.1, width=0.1)
ax = pylab.axes(aspect=1)
ax.add_patch(cir1)
ax.add_patch(cir2)
ax.add_patch(arr)
pylab.show()

# %%
PPF().increase().show()
