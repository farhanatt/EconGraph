# %%
# %matplotlib inline
import EconGraph
from EconGraph import *
import importlib

importlib.reload(EconGraph)
# Out:
# <module 'EconGraph' from '/Users/Farhan/Documents/CMC/DSL/EconGraph/notebooks/EconGraph.py'>

# %%
DemandCurve().increase().show()
SupplyCurve().decrease().show()

# %%
DemandCurve().increase().label_line(3,2).label_line(4,3).show()

# %%
DemandCurve().slope("vertical").show()

# %%
SupplyCurve().increase().show()

# %%
SupplyCurve().decrease().show()

# %%
SupplyCurve().slope("down").show()

# %%
SupplyCurve().slope("horizontal").show()

# %%
SupplyCurve().slope("vertical").show()
DemandCurve().show()

# %%
PPF().show()

# %%
PPF().increase().show()

# %%
PPF().decrease().show()

# %%
PPF().increase().decrease().show()

# %%
PPF().unattainable_point().show()

# %%
plt.plot(1,
         1,
         marker='o',
         fillstyle='full',
         markeredgecolor='red',
         markeredgewidth=1)

# %%
PPF().unattainable_point().show()

# %%
PPF().unattainable_point()
