# %%
# %matplotlib inline
import EconGraph
from EconGraph import *
import importlib
import numpy as np
importlib.reload(EconGraph)
# Out:
# <module 'EconGraph' from '/Users/Farhan/Documents/CMC/DSL/EconGraph/notebooks/EconGraph.py'>

# %%
graph = Graph()
graph.setAxes(0, 100, 0, 100)
graph.plot(
    DemandCurve().decrease(),
    SupplyCurve().increase()
)
# Out:
# self.axes:  [0, 100, 0, 100]
# self.coords_scale:  20.0

# %%
graph = Graph()
graph.setAxes(0, 100, 0, 100)
graph.plot(
    DemandCurve().slope_down(),
    DemandCurve().slope_up(),
    DemandCurve().slope_horizontal(),
    DemandCurve().slope_vertical(),
    DemandCurve()
)

# %%
g=Graph()
g.plot(
    SupplyCurve().increase()
)

# %%
SupplyCurve().show()

# %%
SupplyCurve().slope("down").show()

# %%
SupplyCurve().slope("up").show()

# %%
SupplyCurve().slope("horizontal").show()

# %%
SupplyCurve().slope("vertical").show()
DemandCurve().show()

# %%
Schedule([(5, 3),(6, 2),(7, 1)]).show()
Schedule([(19, 4),(9, 5), (29, 3), (49, 2), (79,1)]).show()

# %%
DemandCurve().increase().slope("up").show()
# Out:
# addToStr

# %%
PPC().show()

# %%
PPC().increase().show()

# %%
PPC().decrease().show()

# %%
PPC().increase().decrease().show()

# %%
PPC().unattainable_point()

# %%
plt.plot(1,
         1,
         marker='o',
         fillstyle='full',
         markeredgecolor='red',
         markeredgewidth=1)

# %%
Schedule([(14, 0), (12, 2), (9, 4), (5, 6), (0, 8)]).show()

# %%
Schedule([(20,0), (19,1), (16,2), (10,3), (0,4)]).show()

# %% [markdown]
# Law of increasing opportunity cost - As you produce more of any good, the opportunity cost will increase.

# %% [markdown]
# Capital goods and future growth

# %%
PPF().show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1184-35543bc14276> in <module>()
# ----> 1 PPF().show()
#
# NameError: name 'PPF' is not defined

# %%
Schedule([(5,0), (4, 100), (3, 180), (2, 240), (1, 280), (0, 300)]).show()

# %%
DemandCurve().label_line(4,3).show()
SupplyCurve().label_line(3,3).show()
# Out:
# addToStr

# %% [markdown]
# If suppliers of the apples decide to sell apples at $1/lb.  Therefore, they only supply 1000 pounds.
#
# Price: $1/lb
# Therefore
# Quantity supplied = 1000lbs
# Quantity demanded = 4000lbs
#
# Therefore, shortage of 3000 apples.
#
# Price will increase since there's a shortage of apples.
# Quantity will also increase because suppliers realize the excess demadn.

# %% [markdown]
# Demand Curve:
#
# Law of Demand: inverse relationship betwene price and Quantity demanded.
#
# Demand schedule - price goes up, quantity demanded goes down.

# %%
DemandCurve().show()

# %% [markdown]
# Reasons curve is downward sloping:
# Substitution effect: changes in price motivate consumers to buy relatively cheaper goods.
#
# Income effect: changes in price affec the purchasing power of consumers' income.
#
# Law of diminishing marginal utility: as you contineu to consume a given product, you will eventually get less additional utility/satisfaction from each unit consumed.

# %% [markdown]
# If anything other than price changes, tehres a demand shift

# %%
DemandCurve().decrease().show()
# Out:
# addToStr

# %%
DemandCurve().increase().show()

# %% [markdown]
# 5 shifters of demand:
# 1. Tastes/preferences
# 2. Number of consumers
# 3. Substitutes
# 4. Complements
# 5. Income
#     - Normal goods: Income increase means demand increase
#     - Inferior goods: income and demand for the product are inversely           related.
#
#
# Expectations
#
#
# Difference in Change in Quantity demanded vs change in demand.

# %%
plt.plot()
plt.axis([0, 10, 0, 10])
# Out:
# [0, 10, 0, 10]

# %%
Graph(0, 5, 0, 5)
DemandCurve.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1191-124a8eabdfa4> in <module>()
# ----> 1 Graph(0, 5, 0, 5)
#       2 DemandCurve.show()
#
# TypeError: __init__() takes 1 positional argument but 5 were given

# %%
Demo.show()

# %%
Graph(0,
      5,
      0,
      5)

# %%
DemandCurve().decrease().label_line(3,4).label_line(1,3).slope("up").__str__()
# Out:
# addToStr
# DemandCurve().decrease()
# addToStr
# DemandCurve().decrease().label_line(3, 4)
# addToStr
# DemandCurve().decrease().label_line(3, 4).label_line(1, 3)
# addToStr
# DemandCurve().decrease().label_line(3, 4).label_line(1, 3).slope(up)
# 'DemandCurve().decrease().label_line(3, 4).label_line(1, 3).slope(up)'

# %%
graph = Graph()
graph.setAxes(0, 5, 0, 5)
graph.plot(DemandCurve().increase())
# Out:
# //anaconda/lib/python3.5/site-packages/matplotlib/axis.py:1017: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "
# //anaconda/lib/python3.5/site-packages/matplotlib/axis.py:1027: UserWarning: Unable to find pixel distance along axis for interval padding of ticks; assuming no interval padding needed.
#   warnings.warn("Unable to find pixel distance along axis "

# %%
DemandCurve().getAxes()
# Out:
# [0, 10, 0, 10]

# %%
plt.figure()
plt.axes()

# %%
graph = Graph()
graph.setAxes(0, 15, 0, 15)
graph.plot(
    DemandCurve().increase(),
    SupplyCurve()
)

# %%
plt.plot([1,2,3,4],[4,3,2,1])
plt.axis([0,10,0,10])
# Out:
# [0, 10, 0, 10]
