# %%
# %matplotlib inline
import EconGraph
from EconGraph import *
import importlib
importlib.reload(EconGraph)
# Out:
# <module 'EconGraph' from '/Users/Farhan/Documents/CMC/DSL/EconGraph/EconGraph.py'>

# %%
DemandCurve().shift("up")
SupplyCurve().shift("down")
