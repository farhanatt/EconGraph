# %%
# %matplotlib inline
import EconGraph
from EconGraph import *
import importlib

importlib.reload(EconGraph)
# Out:
# <module 'EconGraph' from '/Users/Farhan/Documents/CMC/DSL/EconGraph/notebooks/EconGraph.py'>

# %% [markdown]
# # Price Elasticity of Demand
#
# Responsiveness of quantity demanded when there's a change in price.
#
# PED = P/Q x change in Q/change in P

# %%
g = Graph()
g.plot(
    SupplyCurve().decrease_price()
)

# %%
g = Graph()
g.plot(
    DemandCurve().decrease_price()
)

# %%
g = Graph()
g.plot(
    DemandCurve().slope_up().decrease_price()
)

# %%
g = Graph()
g.plot(
    DemandCurve().slope_down().decrease_price()
)
